# %%
#import libraries
import numpy as np
import pandas as pd

# %%
# !pip install numpy pandas
# Out:
# Requirement already satisfied: numpy in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.5.1)
# Requirement already satisfied: pandas in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
data = pd. read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
data.dtypes;
data.select_dtypes(include='object')
data.select_dtypes(include = ['int','float'])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12924\1842530491.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12924\3382516499.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts(ascending=True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts(ascending=True)
# Out:
# Embarked
# Q     77
# C    168
# S    644
# Name: count, dtype: int64

# %%
data['Age'].value_counts(ascending=True)
# Out:
# Age
# 66.0     1
# 14.5     1
# 70.5     1
# 12.0     1
# 36.5     1
#         ..
# 19.0    25
# 30.0    25
# 18.0    26
# 22.0    27
# 24.0    30
# Name: count, Length: 88, dtype: int64

# %%
data['Age'].value_counts().head(30)
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 19.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 26.0    18
# 35.0    18
# 27.0    18
# 32.0    18
# 31.0    17
# 16.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 42.0    13
# 17.0    13
# 45.0    12
# 38.0    11
# 2.0     10
# 4.0     10
# 50.0    10
# 47.0     9
# Name: count, dtype: int64

# %%
data.sample(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 668          669         0       3
# 483          484         1       3
# 444          445         1       3
# 0              1         0       3
# 390          391         1       1
# 263          264         0       1
# 522          523         0       3
# 854          855         0       2
# 656          657         0       3
# 141          142         1       3
# 120          121         0       2
# 836          837         0       3
# 269          270         1       1
# 739          740         0       3
# 335          336         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 668                                Cook, Mr. Jacob    male  43.0      0
# 483                         Turkula, Mrs. (Hedwig)  female  63.0      0
# 444              Johannesen-Bratthammer, Mr. Bernt    male   NaN      0
# 0                          Braund, Mr. Owen Harris    male  22.0      1
# 390                     Carter, Mr. William Ernest    male  36.0      1
# 263                          Harrison, Mr. William    male  40.0      0
# 522                             Lahoud, Mr. Sarkis    male   NaN      0
# 854  Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.0      1
# 656                          Radeff, Mr. Alexander    male   NaN      0
# 141                       Nysten, Miss. Anna Sofia  female  22.0      0
# 120                    Hickman, Mr. Stanley George    male  21.0      2
# 836                               Pasic, Mr. Jakob    male  21.0      0
# 269                         Bissette, Miss. Amelia  female  35.0      0
# 739                             Nankoff, Mr. Minko    male   NaN      0
# 335                             Denkoff, Mr. Mitto    male   NaN      0
#
#      Parch        Ticket      Fare    Cabin Embarked
# 668      0      A/5 3536    8.0500      NaN        S
# 483      0          4134    9.5875      NaN        S
# 444      0         65306    8.1125      NaN        S
# 0        0     A/5 21171    7.2500      NaN        S
# 390      2        113760  120.0000  B96 B98        S
# 263      0        112059    0.0000      B94        S
# 522      0          2624    7.2250      NaN        C
# 854      0        244252   26.0000      NaN        S
# 656      0        349223    7.8958      NaN        S
# 141      0        347081    7.7500      NaN        S
# 120      0  S.O.C. 14879   73.5000      NaN        S
# 836      0        315097    8.6625      NaN        S
# 269      0      PC 17760  135.6333      C99        S
# 739      0        349218    7.8958      NaN        S
# 335      0        349225    7.8958      NaN        S

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.hist(data['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Age'], bins=15, color='purple')
plt.show()

# %%
plt.hist(data['Age'], bins=15, color='gold')
plt.xlabel("Age")
plt.ylabel("count")
plt.title("Age distribution")
plt.show()

# %%
counts, edges, bars = plt.hist(data['Age'], bins=25, color='red')
print(counts)
print(bars)

plt.xlabel("Age")
plt.ylabel("count")
plt.bar_label(bars)
plt.title("Age distribution")
plt.show()
# Out:
# [30. 17. 15.  9. 29. 64. 67. 70. 83. 62. 51. 40. 35. 27. 35. 23. 15.  9.
#  11. 11.  4.  2.  3.  1.  1.]
# <BarContainer object of 25 artists>

# %%
data['Sex'].value_counts().plot(kind='bar')
plt.show()

# %%
data['Pclass'].value_counts().plot(kind='bar')
plt.show()

# %%
data['Embarked'].value_counts().plot(kind='barh', color='pink')
plt.show()

# %%
plt.bar(data['Survived'], data['Sex'])
plt.xlabel("Survived Rate")
plt.ylabel("gender")
plt.title("Gender Survived Distribution")
plt.show()

# %%
data.groupby('Sex')['Survived'].value_counts().unstack().plot(kind='bar')
plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Gender Survived Distribution")
plt.show()

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
index = data['Survived'].value_counts().keys().tolist()
print(index)
labels = data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
plt.pie(
    x=labels,
    labels=['Dead','Alive'],
    colors=['red','yellow'],
    autopct= '%1.1f%%',
    shadow=True
)
plt.title("Survived Distribution")
plt.legend()
plt.show()

# %%
plt.pie(
    x=[577,314],
    labels=['Male','Female'],
    colors=['black','grey'],
    autopct= '%1.1f%%',
    shadow=True
)
plt.title("Gender Distrubution")
plt.legend()
plt.show()

# %%
plt.scatter(x=data['Age'],
            y=data['Fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Age vs Fare distribution")
plt.show()

# %%
import plotly

# %%
# !pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cufflinks) (2.5.1)
# Requirement already satisfied: pandas>=0.19.2 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cufflinks) (3.0.5)
# Requirement already satisfied: plotly>=4.1.1 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cufflinks) (6.9.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cufflinks) (83.0.0)
# Requirement already satisfied: ipython>=5.3.0 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cufflinks) (9.16.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cufflinks) (8.1.8)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.53)
# Requirement already satisfied: psutil>=7 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.16.1)
# Requirement already satisfied: wcwidth>=0.1.4 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2026.3)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from plotly>=4.1.1->cufflinks) (2.24.0)
# Requirement already satisfied: packaging in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from plotly>=4.1.1->cufflinks) (26.3)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.2)
# Requirement already satisfied: pure-eval in C:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)

# %%
import plotly as py
import plotly.graph_objects as go

# %%
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.7.0.min"</script>

# %%
trace = go.Histogram(
    x=data['Age'],
    nbinsx=20,
    marker={'color': 'green'}
)

layout = go.Layout(title='Age Distribution')

fig = go.Figure(data=[trace], layout=layout)

fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3
class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("382e28ad-f50d-463b-aba3-5e0bb1781d64")) {                    Plotly.newPlot(                        "382e28ad-f50d-463b-aba3-5e0bb1781d64",                        [{"labels":["Dead","Alive"],"values":[549,342],"type":"pie"}],                        {"title":{"text":"Survived Distribution"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermap":[{"type":"scattermap","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermapbox":[{"type":"scattermapbox","marker":{"colorbar":{"outlinewidth":0,"ticks": ...
#
# var gd = document.getElementById('382e28ad-f50d-463b-aba3-5e0bb1781d64');
# var x = new MutationObserver(function (mutations, observer) {{

# %%
trace = go.Box(x=data['Pclass'],
               y=data['Age'],
               marker={'color':'red'})
layout = go.Layout(title="Age vs Pclass Distribution")
fig = go.Figure(data=trace,layout = layout)
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="8648486a-459e-4ad8-a272-d418568f56ec" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8648486a-459e-4ad8-a272-d418568f56ec")) {                    Plotly.newPlot(                        "8648486a-459e-4ad8-a272-d418568f56ec",                        [{"marker":{"color":"red"},"x":{"dtype":"i1","bdata":"..."},"y":{"dtype":"f8","bdata":"AAAAAAAANkAAAAAAAABDQAAAAAAAADpAAAAAAACAQUAAAAAAAIBBQAAAAAAAAPh\u002fAAAAAAAAS0AAAAAAAAAAQAAAAAAAADtAAAAAAAAALEAAAAAAAAAQQAAAAAAAAE1AAAAAAAAANEAAAAAAAIBDQAAAAAAAACxAAAAAAACAS0AAAAAAAAAAQAAAAAAAAPh\u002fAAAAAAAAP0AAAAAAAAD4fwAAAAAAgEFAAAAAAAAAQUAAAAAAAAAuQAAAAAAAADxAAAAAAAAAIEAAAAAAAABDQAAAAAAAAPh\u002fAAAAAAAAM0AAAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAAREAAAAAAAAD4fwAAAAAAAPh\u002fAAAAAACAUEAAAAAAAAA8QAAAAAAAAEVAAAAAAAAA+H8AAAAAAAA1QAAAAAAAADJAAAAAAAAALEAAAAAAAABEQAAAAAAAADtAAAAAAAAA+H8AAAAAAAAIQAAAAAAAADNAAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAAyQAAAAAAAABxAAAAAAAAANUAAAAAAAIBIQAAAAAAAAD1AAAAAAABAUEAAAAAAAAD4fwAAAAAAADVAAAAAAACAPEAAAAAAAAAUQAAAAAAAACZAAAAAAAAANkAAAAAAAABDQAAAAAAAgEZAAAAAAAAAEEAAAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAAPUAAAAAAAAAzQAAAAAAAADFAAAAAAAAAOkAAAAAAAABAQAAAAAAAADBAAAAAAAAANUAAAAAAAAA6QAAAAAAAAEBAAAAAAAAAOUAAAAAAAAD4fwAAAAAAAPh\u002fj8L1KFyP6j8AAAAAAAA+QAAAAAAAADZAAAAAAAAAPUAAAAAAAAD4fwAAAAAAADxAAAAAAAAAMUAAAAAAAIBAQAAAAAAAADBAAAAAAAAA+H8AAAAAAAA3QAAAAAAAADhAAAAAAAAAPUAAAAAAAAA0QAAAAAAAAEdAAAAAAAAAOkAAAAAAAIBNQAAAAAAAAPh\u002fAAAAAADAUUAAAAAAAAA3QAAAAAAAAEFAAAAAAAAAQUAAAAAAAAA8QAAAAAAAAPh\u002fAAAAAAAANUAAAAAAAIBAQAAAAAAAgEJAAAAAAAAAPEAAAAAAAAA1QAAAAAAAAPh\u002fAAAAAAAAQ0AAAAAAAAD4fwAAAAAAgEdAAAAAAAAALUAAAAAAA